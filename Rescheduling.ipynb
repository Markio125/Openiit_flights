# %%
pip install gurobipy

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('jan.csv')

# %%
pd.set_option('display.max_rows', None) 
data=df #[df['DAY_OF_MONTH']==2]

data = data.sort_values('CRS_DEP_TIME')

# %%
def convert_hhmm_to_minutes(hhmm):
    hours = hhmm // 100
    minutes = hhmm % 100
    return hours * 60 + minutes
# Convert ScheduledTime column to minutes

data['CRS_ARR_TIME'] = data['CRS_ARR_TIME'].apply(convert_hhmm_to_minutes)
data['CRS_DEP_TIME'] = data['CRS_DEP_TIME'].apply(convert_hhmm_to_minutes)

# %%
def convert_minutes_to_hhmm_string(minutes):
    hours = minutes // 60
    remaining_minutes = minutes % 60
    return f"{hours:02}:{remaining_minutes:02}"  # Format as hh:mm

# %%
data.columns
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK',
#        'OP_UNIQUE_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_AIRPORT_ID', 'ORIGIN', 'ORIGIN_CITY_NAME', 'ORIGIN_STATE_ABR',
#        'DEST_AIRPORT_ID', 'DEST', 'DEST_CITY_NAME', 'DEST_STATE_ABR',
#        'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'TAXI_OUT', 'TAXI_IN',
#        'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY', 'CANCELLED', 'DIVERTED',
#        'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY'],
#       dtype='object')

# %%
import pandas as pd
from gurobipy import Model, GRB

# Load the dataset
data = pd.read_csv('jan.csv')

# Define sets
arrival_flights = data['OP_CARRIER_FL_NUM'][data['DEST'] == 'ATL'].unique().tolist()
departure_flights = data['OP_CARRIER_FL_NUM'][data['ORIGIN'] == 'ATL'].unique().tolist()

# Create a Gurobi model
model = Model('Flight_Rescheduling')

# Decision Variables
u_plus = model.addVars(arrival_flights, vtype=GRB.INTEGER, name='u_plus')
u_minus = model.addVars(arrival_flights, vtype=GRB.INTEGER, name='u_minus')
v_plus = model.addVars(departure_flights, vtype=GRB.INTEGER, name='v_plus')
v_minus = model.addVars(departure_flights, vtype=GRB.INTEGER, name='v_minus')

T = 288  # Number of time slots
# Binary variables for newly scheduled times
w_arr = model.addVars(arrival_flights, range(T), vtype=GRB.BINARY, name='w_arr')
w_dep = model.addVars(departure_flights, range(T), vtype=GRB.BINARY, name='w_dep')

# Objective Function: Minimize total displacements
model.setObjective(
    sum(u_plus[i] + u_minus[i] for i in arrival_flights) +
    sum(v_plus[j] + v_minus[j] for j in departure_flights)+
    sum((sum(w_arr[i, t] for t in range(T)) * 5) - data[data['OP_CARRIER_FL_NUM'] == i]['CRS_ARR_TIME'].values[0] for i in arrival_flights)+
    sum((sum(w_dep[i, t] for t in range(T)) * 5) - data[data['OP_CARRIER_FL_NUM'] == i]['CRS_DEP_TIME'].values[0] for i in departure_flights),
    GRB.MINIMIZE
)

# Constraints
# Ensure all flights are scheduled (at least one time slot must be used)
for i in arrival_flights:
    model.addConstr(sum(w_arr[i, t] for t in range(T)) >= 1, name=f'initial_arrival_{i}')
    
for j in departure_flights:
    model.addConstr(sum(w_dep[j, t] for t in range(T)) >= 1, name=f'initial_departure_{j}')

#Rescheduled time constraints
for i in arrival_flights:
    model.addConstr(
        sum(w_arr[i, t] for t in range(T))*5  == u_plus[i] - u_minus[i],
        name=f'rescheduled_arrival_{i}'
    )
    
for j in departure_flights:
    model.addConstr(
        sum(w_dep[j, t] for t in range(T))*5  == v_plus[j] - v_minus[j],
        name=f'rescheduled_departure_{j}'
    )
#- data[data['OP_CARRIER_FL_NUM'] == i]['CRS_DEP_TIME'].values[0]
# Capacity constraints
for t in range(T):
    model.addConstr(
        sum(w_arr[i, t] for i in arrival_flights) <= 10,  # Ensure this matches realistic airport operations
        name=f'capacity_arrival_{t}'
    )
    
    model.addConstr(
        sum(w_dep[j, t] for j in departure_flights) <= 15,  # Same as above
        name=f'capacity_departure_{t}'
    )

# Set maximum displacements
model.addConstrs((u_plus[i] <= 60 for i in arrival_flights), name='max_pos_displacement_arrival')
model.addConstrs((u_minus[i] <= 15 for i in arrival_flights), name='max_neg_displacement_arrival')
model.addConstrs((v_plus[j] <= 60 for j in departure_flights), name='max_pos_displacement_departure')
model.addConstrs((v_minus[j] <= 15 for j in departure_flights), name='max_neg_displacement_departure')

# Optimize the model
model.optimize()

# Check the status of the model
if model.status == GRB.OPTIMAL:
    print("Optimal scheduling found:")
    for i in arrival_flights:
        new_schedule = sum(t * w_arr[i, t].X for t in range(T) if w_arr[i, t].X > 0)
        print(f"Flight {i}: New Schedule = {new_schedule}")
    
    for j in departure_flights:
        new_schedule = sum(t * w_dep[j, t].X for t in range(T) if w_dep[j, t].X > 0)
        print(f"Flight {j}: New Schedule = {new_schedule}")
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14428 rows, 1004270 columns and 3005884 nonzeros
# Model fingerprint: 0x022a3941
# Variable types: 0 continuous, 1004270 integer (997344 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Presolve removed 12395 rows and 499965 columns (presolve time = 7s) ...
# Presolve removed 12395 rows and 499965 columns
# Presolve time: 7.44s
# Presolved: 2033 rows, 504305 columns, 1006865 nonzeros
# Variable types: 0 continuous, 504305 integer (502560 binary)
# Found heuristic solution: objective -5067395.000
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.09s
#
# Barrier statistics:
#  AA' NZ     : 5.026e+05
#  Factor NZ  : 6.042e+05 (roughly 200 MB of memory)
#  Factor Ops : 1.957e+08 (less than 1 second per iteration)
#  Threads    : 2
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.97365041e+07 -9.46465733e+06  1.71e+04 0.00e+00  1.13e+02    11s
#    1  -5.05406805e+06 -8.67826461e+06  7.29e-12 7.11e-15  3.59e+00    11s
#
# Barrier performed 1 iterations in 10.88 seconds (5.75 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.50s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 1745 iterations, 1.90 seconds (0.57 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      -5067395.0 -5067395.0  0.00%     -   10s
#
# Explored 1 nodes (1745 simplex iterations) in 11.07 seconds (5.75 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: -5.0674e+06
# No other solutions better than -5.0674e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.067395000000e+06, best bound -5.067395000000e+06, gap 0.0000%
# Optimal scheduling found:
# Flight 5076: New Schedule = 254.0
# Flight 5483: New Schedule = 158.0
# Flight 5232: New Schedule = 165.0
# Flight 5301: New Schedule = 103.0
# Flight 4815: New Schedule = 244.0
# Flight 5544: New Schedule = 155.0
# Flight 5358: New Schedule = 273.0
# Flight 5025: New Schedule = 116.0
# Flight 4672: New Schedule = 208.0
# Flight 4855: New Schedule = 246.0
# Flight 5147: New Schedule = 126.0
# Flight 5318: New Schedule = 129.0
# Flight 5250: New Schedule = 236.0
# Flight 5255: New Schedule = 148.0
# Flight 5170: New Schedule = 275.0
# Flight 5540: New Schedule = 191.0
# Flight 4667: New Schedule = 159.0
# Flight 5120: New Schedule = 238.0
# Flight 4954: New Schedule = 281.0
# Flight 4740: New Schedule = 130.0
# Flight 5201: New Schedule = 223.0
# Flight 5394: New Schedule = 26.0
# Flight 5547: New Schedule = 285.0
# Flight 4729: New Schedule = 158.0
# Flight 5055: New Schedule = 4.0
# Flight 5082: New Schedule = 186.0
# Flight 5411: New Schedule = 92.0
# Flight 4794: New Schedule = 98.0
# Flight 5108: New Schedule = 127.0
# Flight 4861: New Schedule = 86.0
# Flight 4864: New Schedule = 132.0
# Flight 4639: New Schedule = 30.0
# Flight 4887: New Schedule = 64.0
# Flight 4825: New Schedule = 250.0
# Flight 5143: New Schedule = 49.0
# Flight 5531: New Schedule = 1.0
# Flight 4789: New Schedule = 86.0
# Flight 5040: New Schedule = 52.0
# Flight 4684: New Schedule = 121.0
# Flight 4941: New Schedule = 111.0
# Flight 5448: New Schedule = 84.0
# Flight 4972: New Schedule = 112.0
# Flight 5392: New Schedule = 235.0
# Flight 5459: New Schedule = 269.0
# Flight 5480: New Schedule = 148.0
# Flight 4851: New Schedule = 227.0
# Flight 5211: New Schedule = 164.0
# Flight 4874: New Schedule = 279.0
# Flight 5278: New Schedule = 216.0
# Flight 5240: New Schedule = 109.0
# Flight 4830: New Schedule = 272.0
# Flight 4711: New Schedule = 231.0
# Flight 5163: New Schedule = 67.0
# Flight 4666: New Schedule = 39.0
# Flight 5251: New Schedule = 142.0
# Flight 4807: New Schedule = 75.0
# Flight 5432: New Schedule = 274.0
# Flight 5089: New Schedule = 19.0
# Flight 5495: New Schedule = 195.0
# Flight 328: New Schedule = 77.0
# Flight 2749: New Schedule = 26.0
# Flight 2403: New Schedule = 196.0
# Flight 462: New Schedule = 188.0
# Flight 2366: New Schedule = 199.0
# Flight 507: New Schedule = 41.0
# Flight 763: New Schedule = 107.0
# Flight 1411: New Schedule = 42.0
# Flight 1051: New Schedule = 46.0
# Flight 2040: New Schedule = 160.0
# Flight 2174: New Schedule = 18.0
# Flight 2192: New Schedule = 229.0
# Flight 1181: New Schedule = 267.0
# Flight 2286: New Schedule = 36.0
# Flight 1006: New Schedule = 224.0
# Flight 1045: New Schedule = 14.0
# Flight 990: New Schedule = 106.0
# Flight 2072: New Schedule = 109.0
# Flight 723: New Schedule = 242.0
# Flight 442: New Schedule = 42.0
# Flight 746: New Schedule = 142.0
# Flight 697: New Schedule = 278.0
# Flight 319: New Schedule = 16.0
# Flight 1719: New Schedule = 137.0
# Flight 568: New Schedule = 88.0
# Flight 419: New Schedule = 171.0
# Flight 1569: New Schedule = 212.0
# Flight 1672: New Schedule = 206.0
# Flight 2811: New Schedule = 132.0
# Flight 403: New Schedule = 125.0
# Flight 491: New Schedule = 187.0
# Flight 820: New Schedule = 230.0
# Flight 1252: New Schedule = 180.0
# Flight 364: New Schedule = 103.0
# Flight 1026: New Schedule = 245.0
# Flight 2218: New Schedule = 223.0
# Flight 407: New Schedule = 135.0
# Flight 809: New Schedule = 8.0
# Flight 1001: New Schedule = 34.0
# Flight 1144: New Schedule = 198.0
# Flight 1616: New Schedule = 121.0
# Flight 2021: New Schedule = 168.0
# Flight 1295: New Schedule = 98.0
# Flight 2053: New Schedule = 190.0
# Flight 1213: New Schedule = 262.0
# Flight 1741: New Schedule = 47.0
# Flight 2301: New Schedule = 256.0
# Flight 752: New Schedule = 155.0
# Flight 309: New Schedule = 5.0
# Flight 1701: New Schedule = 119.0
# Flight 423: New Schedule = 179.0
# Flight 1346: New Schedule = 225.0
# Flight 1599: New Schedule = 147.0
# Flight 1111: New Schedule = 174.0
# Flight 1648: New Schedule = 75.0
# Flight 1644: New Schedule = 16.0
# Flight 2723: New Schedule = 118.0
# Flight 2486: New Schedule = 97.0
# Flight 2862: New Schedule = 248.0
# Flight 2991: New Schedule = 107.0
# Flight 740: New Schedule = 282.0
# Flight 755: New Schedule = 274.0
# Flight 819: New Schedule = 1.0
# Flight 2126: New Schedule = 139.0
# Flight 398: New Schedule = 169.0
# Flight 1585: New Schedule = 105.0
# Flight 2868: New Schedule = 234.0
# Flight 1511: New Schedule = 178.0
# Flight 441: New Schedule = 161.0
# Flight 1421: New Schedule = 241.0
# Flight 2008: New Schedule = 80.0
# Flight 357: New Schedule = 255.0
# Flight 1613: New Schedule = 118.0
# Flight 2512: New Schedule = 5.0
# Flight 2836: New Schedule = 15.0
# Flight 2702: New Schedule = 147.0
# Flight 2808: New Schedule = 235.0
# Flight 1079: New Schedule = 94.0
# Flight 1631: New Schedule = 71.0
# Flight 1217: New Schedule = 280.0
# Flight 1379: New Schedule = 261.0
# Flight 1293: New Schedule = 180.0
# Flight 414: New Schedule = 221.0
# Flight 1168: New Schedule = 128.0
# Flight 2337: New Schedule = 241.0
# Flight 2500: New Schedule = 7.0
# Flight 1545: New Schedule = 55.0
# Flight 1433: New Schedule = 109.0
# Flight 575: New Schedule = 16.0
# Flight 2050: New Schedule = 97.0
# Flight 2698: New Schedule = 5.0
# Flight 694: New Schedule = 71.0
# Flight 492: New Schedule = 105.0
# Flight 1253: New Schedule = 84.0
# Flight 2743: New Schedule = 98.0
# Flight 464: New Schedule = 160.0
# Flight 1592: New Schedule = 45.0
# Flight 2461: New Schedule = 244.0
# Flight 1273: New Schedule = 132.0
# Flight 805: New Schedule = 178.0
# Flight 1434: New Schedule = 17.0
# Flight 2180: New Schedule = 47.0
# Flight 447: New Schedule = 83.0
# Flight 982: New Schedule = 272.0
# Flight 2124: New Schedule = 70.0
# Flight 2026: New Schedule = 238.0
# Flight 2716: New Schedule = 137.0
# Flight 2924: New Schedule = 15.0
# Flight 1196: New Schedule = 11.0
# Flight 1454: New Schedule = 197.0
# Flight 2476: New Schedule = 130.0
# Flight 388: New Schedule = 158.0
# Flight 433: New Schedule = 228.0
# Flight 367: New Schedule = 250.0
# Flight 527: New Schedule = 87.0
# Flight 2591: New Schedule = 115.0
# Flight 382: New Schedule = 65.0
# Flight 2068: New Schedule = 168.0
# Flight 478: New Schedule = 206.0
# Flight 1267: New Schedule = 175.0
# Flight 2314: New Schedule = 44.0
# Flight 2798: New Schedule = 231.0
# Flight 395: New Schedule = 282.0
# Flight 1444: New Schedule = 260.0
# Flight 2469: New Schedule = 6.0
# Flight 818: New Schedule = 191.0
# Flight 1315: New Schedule = 90.0
# Flight 2341: New Schedule = 210.0
# Flight 2848: New Schedule = 239.0
# Flight 529: New Schedule = 167.0
# Flight 32: New Schedule = 230.0
# Flight 405: New Schedule = 17.0
# Flight 2239: New Schedule = 228.0
# Flight 2638: New Schedule = 20.0
# Flight 365: New Schedule = 18.0
# Flight 1660: New Schedule = 145.0
# Flight 702: New Schedule = 65.0
# Flight 457: New Schedule = 49.0
# Flight 2141: New Schedule = 247.0
# Flight 940: New Schedule = 113.0
# Flight 2639: New Schedule = 12.0
# Flight 2417: New Schedule = 190.0
# Flight 2511: New Schedule = 225.0
# Flight 1129: New Schedule = 244.0
# Flight 2508: New Schedule = 199.0
# Flight 2642: New Schedule = 8.0
# Flight 1284: New Schedule = 180.0
# Flight 2678: New Schedule = 210.0
# Flight 306: New Schedule = 109.0
# Flight 2115: New Schedule = 161.0
# Flight 1560: New Schedule = 43.0
# Flight 2585: New Schedule = 63.0
# Flight 1647: New Schedule = 171.0
# Flight 360: New Schedule = 185.0
# Flight 377: New Schedule = 284.0
# Flight 2291: New Schedule = 259.0
# Flight 2363: New Schedule = 117.0
# Flight 2355: New Schedule = 184.0
# Flight 727: New Schedule = 199.0
# Flight 1522: New Schedule = 175.0
# Flight 2146: New Schedule = 247.0
# Flight 528: New Schedule = 198.0
# Flight 945: New Schedule = 103.0
# Flight 1184: New Schedule = 89.0
# Flight 2758: New Schedule = 76.0
# Flight 684: New Schedule = 266.0
# Flight 2080: New Schedule = 148.0
# Flight 2917: New Schedule = 170.0
# Flight 426: New Schedule = 206.0
# Flight 2692: New Schedule = 60.0
# Flight 2795: New Schedule = 45.0
# Flight 823: New Schedule = 177.0
# Flight 2387: New Schedule = 174.0
# Flight 2773: New Schedule = 120.0
# Flight 2060: New Schedule = 66.0
# Flight 1469: New Schedule = 235.0
# Flight 2939: New Schedule = 156.0
# Flight 345: New Schedule = 225.0
# Flight 2135: New Schedule = 196.0
# Flight 862: New Schedule = 96.0
# Flight 523: New Schedule = 85.0
# Flight 998: New Schedule = 123.0
# Flight 1336: New Schedule = 118.0
# Flight 887: New Schedule = 263.0
# Flight 2610: New Schedule = 140.0
# Flight 2161: New Schedule = 269.0
# Flight 2997: New Schedule = 154.0
# Flight 2643: New Schedule = 252.0
# Flight 408: New Schedule = 42.0
# Flight 864: New Schedule = 23.0
# Flight 1198: New Schedule = 42.0
# Flight 2669: New Schedule = 51.0
# Flight 2569: New Schedule = 32.0
# Flight 1386: New Schedule = 107.0
# Flight 1809: New Schedule = 51.0
# Flight 1593: New Schedule = 8.0
# Flight 506: New Schedule = 216.0
# Flight 970: New Schedule = 179.0
# Flight 2979: New Schedule = 202.0
# Flight 2593: New Schedule = 43.0
# Flight 410: New Schedule = 212.0
# Flight 2233: New Schedule = 214.0
# Flight 1416: New Schedule = 14.0
# Flight 1651: New Schedule = 184.0
# Flight 2890: New Schedule = 117.0
# Flight 8788: New Schedule = 144.0
# Flight 369: New Schedule = 206.0
# Flight 1262: New Schedule = 285.0
# Flight 1490: New Schedule = 162.0
# Flight 2938: New Schedule = 42.0
# Flight 2907: New Schedule = 55.0
# Flight 1670: New Schedule = 146.0
# Flight 1408: New Schedule = 73.0
# Flight 1075: New Schedule = 242.0
# Flight 769: New Schedule = 204.0
# Flight 783: New Schedule = 230.0
# Flight 2822: New Schedule = 181.0
# Flight 929: New Schedule = 65.0
# Flight 550: New Schedule = 81.0
# Flight 1234: New Schedule = 128.0
# Flight 356: New Schedule = 225.0
# Flight 1475: New Schedule = 267.0
# Flight 1541: New Schedule = 52.0
# Flight 1437: New Schedule = 84.0
# Flight 496: New Schedule = 204.0
# Flight 715: New Schedule = 109.0
# Flight 1151: New Schedule = 284.0
# Flight 479: New Schedule = 46.0
# Flight 674: New Schedule = 134.0
# Flight 1266: New Schedule = 145.0
# Flight 870: New Schedule = 15.0
# Flight 836: New Schedule = 119.0
# Flight 1254: New Schedule = 83.0
# Flight 2928: New Schedule = 82.0
# Flight 883: New Schedule = 132.0
# Flight 1373: New Schedule = 110.0
# Flight 2962: New Schedule = 222.0
# Flight 1544: New Schedule = 209.0
# Flight 2622: New Schedule = 64.0
# Flight 2580: New Schedule = 269.0
# Flight 859: New Schedule = 241.0
# Flight 831: New Schedule = 82.0
# Flight 1438: New Schedule = 201.0
# Flight 2753: New Schedule = 254.0
# Flight 2166: New Schedule = 254.0
# Flight 634: New Schedule = 96.0
# Flight 1496: New Schedule = 15.0
# Flight 2150: New Schedule = 143.0
# Flight 741: New Schedule = 37.0
# Flight 807: New Schedule = 23.0
# Flight 2211: New Schedule = 19.0
# Flight 2502: New Schedule = 151.0
# Flight 949: New Schedule = 121.0
# Flight 1601: New Schedule = 40.0
# Flight 2209: New Schedule = 217.0
# Flight 1431: New Schedule = 106.0
# Flight 2596: New Schedule = 148.0
# Flight 2825: New Schedule = 42.0
# Flight 778: New Schedule = 23.0
# Flight 1696: New Schedule = 271.0
# Flight 484: New Schedule = 140.0
# Flight 2274: New Schedule = 44.0
# Flight 530: New Schedule = 230.0
# Flight 2553: New Schedule = 159.0
# Flight 762: New Schedule = 87.0
# Flight 1418: New Schedule = 49.0
# Flight 1513: New Schedule = 88.0
# Flight 2359: New Schedule = 283.0
# Flight 475: New Schedule = 109.0
# Flight 941: New Schedule = 244.0
# Flight 1654: New Schedule = 24.0
# Flight 672: New Schedule = 70.0
# Flight 1633: New Schedule = 171.0
# Flight 1470: New Schedule = 171.0
# Flight 1556: New Schedule = 191.0
# Flight 2253: New Schedule = 174.0
# Flight 2259: New Schedule = 204.0
# Flight 768: New Schedule = 269.0
# Flight 1480: New Schedule = 162.0
# Flight 1532: New Schedule = 53.0
# Flight 2272: New Schedule = 184.0
# Flight 866: New Schedule = 44.0
# Flight 1406: New Schedule = 91.0
# Flight 996: New Schedule = 156.0
# Flight 1763: New Schedule = 65.0
# Flight 2319: New Schedule = 109.0
# Flight 2290: New Schedule = 109.0
# Flight 474: New Schedule = 70.0
# Flight 2288: New Schedule = 69.0
# Flight 1671: New Schedule = 13.0
# Flight 375: New Schedule = 21.0
# Flight 2703: New Schedule = 223.0
# Flight 437: New Schedule = 140.0
# Flight 824: New Schedule = 209.0
# Flight 1005: New Schedule = 279.0
# Flight 1424: New Schedule = 155.0
# Flight 1415: New Schedule = 211.0
# Flight 1550: New Schedule = 194.0
# Flight 2774: New Schedule = 144.0
# Flight 729: New Schedule = 208.0
# Flight 863: New Schedule = 90.0
# Flight 1064: New Schedule = 230.0
# Flight 2445: New Schedule = 9.0
# Flight 430: New Schedule = 160.0
# Flight 892: New Schedule = 163.0
# Flight 2452: New Schedule = 98.0
# Flight 2628: New Schedule = 28.0
# Flight 2297: New Schedule = 25.0
# Flight 841: New Schedule = 266.0
# Flight 373: New Schedule = 267.0
# Flight 2034: New Schedule = 182.0
# Flight 1243: New Schedule = 197.0
# Flight 1731: New Schedule = 96.0
# Flight 2816: New Schedule = 15.0
# Flight 2824: New Schedule = 275.0
# Flight 1161: New Schedule = 235.0
# Flight 1732: New Schedule = 149.0
# Flight 1029: New Schedule = 84.0
# Flight 906: New Schedule = 171.0
# Flight 1349: New Schedule = 258.0
# Flight 2539: New Schedule = 284.0
# Flight 2782: New Schedule = 171.0
# Flight 2489: New Schedule = 6.0
# Flight 520: New Schedule = 235.0
# Flight 2336: New Schedule = 47.0
# Flight 2935: New Schedule = 105.0
# Flight 2564: New Schedule = 129.0
# Flight 1229: New Schedule = 96.0
# Flight 555: New Schedule = 76.0
# Flight 1409: New Schedule = 143.0
# Flight 898: New Schedule = 146.0
# Flight 1676: New Schedule = 74.0
# Flight 2096: New Schedule = 215.0
# Flight 2617: New Schedule = 20.0
# Flight 434: New Schedule = 229.0
# Flight 716: New Schedule = 61.0
# Flight 1351: New Schedule = 254.0
# Flight 2281: New Schedule = 117.0
# Flight 1535: New Schedule = 110.0
# Flight 424: New Schedule = 103.0
# Flight 2306: New Schedule = 133.0
# Flight 2732: New Schedule = 76.0
# Flight 757: New Schedule = 101.0
# Flight 939: New Schedule = 73.0
# Flight 2332: New Schedule = 154.0
# Flight 482: New Schedule = 162.0
# Flight 2842: New Schedule = 194.0
# Flight 878: New Schedule = 15.0
# Flight 2440: New Schedule = 81.0
# Flight 2645: New Schedule = 77.0
# Flight 662: New Schedule = 45.0
# Flight 1094: New Schedule = 101.0
# Flight 1484: New Schedule = 190.0
# Flight 2421: New Schedule = 281.0
# Flight 2364: New Schedule = 52.0
# Flight 921: New Schedule = 201.0
# Flight 1245: New Schedule = 82.0
# Flight 2092: New Schedule = 176.0
# Flight 2304: New Schedule = 155.0
# Flight 1693: New Schedule = 94.0
# Flight 889: New Schedule = 67.0
# Flight 1736: New Schedule = 269.0
# Flight 2810: New Schedule = 29.0
# Flight 1244: New Schedule = 33.0
# Flight 2878: New Schedule = 133.0
# Flight 999: New Schedule = 39.0
# Flight 1553: New Schedule = 90.0
# Flight 761: New Schedule = 273.0
# Flight 1298: New Schedule = 226.0
# Flight 1458: New Schedule = 159.0
# Flight 2892: New Schedule = 154.0
# Flight 450: New Schedule = 68.0
# Flight 1089: New Schedule = 20.0
# Flight 470: New Schedule = 29.0
# Flight 1543: New Schedule = 196.0
# Flight 2487: New Schedule = 103.0
# Flight 458: New Schedule = 245.0
# Flight 2108: New Schedule = 26.0
# Flight 1495: New Schedule = 115.0
# Flight 1589: New Schedule = 65.0
# Flight 2672: New Schedule = 32.0
# Flight 912: New Schedule = 56.0
# Flight 961: New Schedule = 278.0
# Flight 1668: New Schedule = 21.0
# Flight 1697: New Schedule = 40.0
# Flight 1033: New Schedule = 55.0
# Flight 1691: New Schedule = 86.0
# Flight 2120: New Schedule = 95.0
# Flight 2864: New Schedule = 29.0
# Flight 572: New Schedule = 83.0
# Flight 2727: New Schedule = 188.0
# Flight 858: New Schedule = 8.0
# Flight 1023: New Schedule = 33.0
# Flight 1675: New Schedule = 178.0
# Flight 1355: New Schedule = 85.0
# Flight 1530: New Schedule = 90.0
# Flight 2152: New Schedule = 140.0
# Flight 302: New Schedule = 13.0
# Flight 1398: New Schedule = 84.0
# Flight 2087: New Schedule = 105.0
# Flight 2545: New Schedule = 240.0
# Flight 2853: New Schedule = 19.0
# Flight 951: New Schedule = 171.0
# Flight 2293: New Schedule = 202.0
# Flight 400: New Schedule = 70.0
# Flight 1246: New Schedule = 116.0
# Flight 1362: New Schedule = 114.0
# Flight 1537: New Schedule = 109.0
# Flight 994: New Schedule = 232.0
# Flight 1193: New Schedule = 174.0
# Flight 1240: New Schedule = 195.0
# Flight 1512: New Schedule = 91.0
# Flight 2518: New Schedule = 282.0
# Flight 1197: New Schedule = 116.0
# Flight 2179: New Schedule = 37.0
# Flight 2937: New Schedule = 230.0
# Flight 2823: New Schedule = 235.0
# Flight 541: New Schedule = 258.0
# Flight 2695: New Schedule = 74.0
# Flight 2266: New Schedule = 265.0
# Flight 2670: New Schedule = 59.0
# Flight 1554: New Schedule = 200.0
# Flight 2041: New Schedule = 95.0
# Flight 2282: New Schedule = 162.0
# Flight 445: New Schedule = 218.0
# Flight 1256: New Schedule = 25.0
# Flight 2400: New Schedule = 209.0
# Flight 1081: New Schedule = 49.0
# Flight 2495: New Schedule = 30.0
# Flight 2745: New Schedule = 131.0
# Flight 652: New Schedule = 234.0
# Flight 681: New Schedule = 242.0
# Flight 1745: New Schedule = 184.0
# Flight 784: New Schedule = 190.0
# Flight 1491: New Schedule = 74.0
# Flight 1688: New Schedule = 246.0
# Flight 2614: New Schedule = 35.0
# Flight 1147: New Schedule = 3.0
# Flight 2003: New Schedule = 232.0
# Flight 1278: New Schedule = 179.0
# Flight 1345: New Schedule = 4.0
# Flight 1427: New Schedule = 240.0
# Flight 2340: New Schedule = 28.0
# Flight 8789: New Schedule = 208.0
# Flight 1514: New Schedule = 37.0
# Flight 2597: New Schedule = 164.0
# Flight 2984: New Schedule = 241.0
# Flight 493: New Schedule = 102.0
# Flight 1518: New Schedule = 118.0
# Flight 416: New Schedule = 39.0
# Flight 418: New Schedule = 87.0
# Flight 1498: New Schedule = 110.0
# Flight 2000: New Schedule = 153.0
# Flight 2550: New Schedule = 212.0
# Flight 1575: New Schedule = 39.0
# Flight 1578: New Schedule = 232.0
# Flight 1015: New Schedule = 18.0
# Flight 1562: New Schedule = 254.0
# Flight 1591: New Schedule = 27.0
# Flight 1571: New Schedule = 88.0
# Flight 1365: New Schedule = 118.0
# Flight 1515: New Schedule = 83.0
# Flight 101: New Schedule = 257.0
# Flight 1524: New Schedule = 277.0
# Flight 2002: New Schedule = 13.0
# Flight 1013: New Schedule = 49.0
# Flight 1559: New Schedule = 278.0
# Flight 1699: New Schedule = 101.0
# Flight 2385: New Schedule = 121.0
# Flight 3451: New Schedule = 200.0
# Flight 3550: New Schedule = 254.0
# Flight 4013: New Schedule = 212.0
# Flight 1436: New Schedule = 254.0
# Flight 2327: New Schedule = 96.0
# Flight 2647: New Schedule = 216.0
# Flight 98: New Schedule = 62.0
# Flight 635: New Schedule = 214.0
# Flight 640: New Schedule = 270.0
# Flight 3100: New Schedule = 265.0
# Flight 1146: New Schedule = 254.0
# Flight 2330: New Schedule = 69.0
# Flight 1210: New Schedule = 2.0
# Flight 3878: New Schedule = 33.0
# Flight 41: New Schedule = 179.0
# Flight 230: New Schedule = 155.0
# Flight 251: New Schedule = 46.0
# Flight 362: New Schedule = 192.0
# Flight 1175: New Schedule = 19.0
# Flight 806: New Schedule = 53.0
# Flight 1025: New Schedule = 82.0
# Flight 1305: New Schedule = 279.0
# Flight 962: New Schedule = 200.0
# Flight 1078: New Schedule = 272.0
# Flight 565: New Schedule = 95.0
# Flight 631: New Schedule = 86.0
# Flight 383: New Schedule = 281.0
# Flight 770: New Schedule = 208.0
# Flight 1826: New Schedule = 88.0
# Flight 1177: New Schedule = 279.0
# Flight 1080: New Schedule = 185.0
# Flight 163: New Schedule = 145.0
# Flight 1082: New Schedule = 98.0
# Flight 877: New Schedule = 166.0
# Flight 1828: New Schedule = 139.0
# Flight 1232: New Schedule = 215.0
# Flight 1561: New Schedule = 59.0
# Flight 452: New Schedule = 281.0
# Flight 1837: New Schedule = 231.0
# Flight 1894: New Schedule = 4.0
# Flight 5375: New Schedule = 135.0
# Flight 5125: New Schedule = 268.0
# Flight 4032: New Schedule = 109.0
# Flight 3890: New Schedule = 223.0
# Flight 4524: New Schedule = 7.0
# Flight 3589: New Schedule = 153.0
# Flight 4500: New Schedule = 274.0
# Flight 4515: New Schedule = 196.0
# Flight 3593: New Schedule = 59.0
# Flight 3699: New Schedule = 103.0
# Flight 4041: New Schedule = 244.0
# Flight 4051: New Schedule = 211.0
# Flight 3662: New Schedule = 113.0
# Flight 3597: New Schedule = 22.0
# Flight 3996: New Schedule = 96.0
# Flight 4122: New Schedule = 263.0
# Flight 4149: New Schedule = 8.0
# Flight 4010: New Schedule = 216.0
# Flight 3997: New Schedule = 221.0
# Flight 4035: New Schedule = 75.0
# Flight 4159: New Schedule = 56.0
# Flight 730: New Schedule = 199.0
# Flight 1596: New Schedule = 238.0
# Flight 237: New Schedule = 21.0
# Flight 1308: New Schedule = 161.0
# Flight 753: New Schedule = 187.0
# Flight 1682: New Schedule = 75.0
# Flight 2606: New Schedule = 18.0
# Flight 1156: New Schedule = 104.0
# Flight 686: New Schedule = 238.0
# Flight 1283: New Schedule = 217.0
# Flight 1871: New Schedule = 33.0
# Flight 2471: New Schedule = 106.0
# Flight 3626: New Schedule = 260.0
# Flight 2358: New Schedule = 235.0
# Flight 3674: New Schedule = 93.0
# Flight 914: New Schedule = 285.0
# Flight 2884: New Schedule = 94.0
# Flight 3040: New Schedule = 234.0
# Flight 1624: New Schedule = 149.0
# Flight 3130: New Schedule = 10.0
# Flight 397: New Schedule = 55.0
# Flight 2983: New Schedule = 63.0
# Flight 160: New Schedule = 9.0
# Flight 1860: New Schedule = 149.0
# Flight 3026: New Schedule = 158.0
# Flight 2279: New Schedule = 6.0
# Flight 3498: New Schedule = 164.0
# Flight 1932: New Schedule = 277.0
# Flight 732: New Schedule = 249.0
# Flight 987: New Schedule = 61.0
# Flight 1135: New Schedule = 221.0
# Flight 3789: New Schedule = 3.0
# Flight 1534: New Schedule = 138.0
# Flight 2262: New Schedule = 200.0
# Flight 147: New Schedule = 234.0
# Flight 570: New Schedule = 250.0
# Flight 2075: New Schedule = 15.0
# Flight 2592: New Schedule = 157.0
# Flight 1821: New Schedule = 225.0
# Flight 1980: New Schedule = 261.0
# Flight 342: New Schedule = 260.0
# Flight 1095: New Schedule = 162.0
# Flight 1733: New Schedule = 110.0
# Flight 1400: New Schedule = 99.0
# Flight 2648: New Schedule = 53.0
# Flight 606: New Schedule = 75.0
# Flight 2572: New Schedule = 231.0
# Flight 1849: New Schedule = 59.0
# Flight 1974: New Schedule = 48.0
# Flight 378: New Schedule = 176.0
# Flight 3254: New Schedule = 28.0
# Flight 2980: New Schedule = 31.0
# Flight 3070: New Schedule = 46.0
# Flight 512: New Schedule = 242.0
# Flight 3054: New Schedule = 99.0
# Flight 2671: New Schedule = 63.0
# Flight 200: New Schedule = 46.0
# Flight 3281: New Schedule = 173.0
# Flight 314: New Schedule = 133.0
# Flight 2505: New Schedule = 34.0
# Flight 1054: New Schedule = 202.0
# Flight 184: New Schedule = 205.0
# Flight 1076: New Schedule = 201.0
# Flight 3571: New Schedule = 33.0
# Flight 191: New Schedule = 14.0
# Flight 1375: New Schedule = 232.0
# Flight 451: New Schedule = 118.0
# Flight 792: New Schedule = 106.0
# Flight 3232: New Schedule = 161.0
# Flight 2: New Schedule = 230.0
# Flight 4445: New Schedule = 91.0
# Flight 1622: New Schedule = 147.0
# Flight 535: New Schedule = 111.0
# Flight 872: New Schedule = 161.0
# Flight 2735: New Schedule = 143.0
# Flight 2234: New Schedule = 124.0
# Flight 3093: New Schedule = 58.0
# Flight 1099: New Schedule = 26.0
# Flight 2396: New Schedule = 236.0
# Flight 508: New Schedule = 48.0
# Flight 3075: New Schedule = 155.0
# Flight 713: New Schedule = 183.0
# Flight 683: New Schedule = 226.0
# Flight 303: New Schedule = 89.0
# Flight 26: New Schedule = 71.0
# Flight 3497: New Schedule = 33.0
# Flight 182: New Schedule = 42.0
# Flight 2783: New Schedule = 78.0
# Flight 2390: New Schedule = 198.0
# Flight 4674: New Schedule = 45.0
# Flight 4442: New Schedule = 68.0
# Flight 4902: New Schedule = 68.0
# Flight 4717: New Schedule = 226.0
# Flight 4840: New Schedule = 158.0
# Flight 5101: New Schedule = 224.0
# Flight 5141: New Schedule = 70.0
# Flight 5245: New Schedule = 209.0
# Flight 5083: New Schedule = 50.0
# Flight 5252: New Schedule = 187.0
# Flight 4943: New Schedule = 226.0
# Flight 5280: New Schedule = 134.0
# Flight 5440: New Schedule = 87.0
# Flight 4781: New Schedule = 263.0
# Flight 5129: New Schedule = 226.0
# Flight 5131: New Schedule = 139.0
# Flight 4849: New Schedule = 199.0
# Flight 5014: New Schedule = 180.0
# Flight 5172: New Schedule = 260.0
# Flight 5008: New Schedule = 188.0
# Flight 5359: New Schedule = 193.0
# Flight 5263: New Schedule = 105.0
# Flight 4714: New Schedule = 193.0
# Flight 5484: New Schedule = 77.0
# Flight 5105: New Schedule = 152.0
# Flight 4769: New Schedule = 81.0
# Flight 4936: New Schedule = 168.0
# Flight 5223: New Schedule = 206.0
# Flight 5393: New Schedule = 44.0
# Flight 5049: New Schedule = 168.0
# Flight 283: New Schedule = 154.0
# Flight 519: New Schedule = 83.0
# Flight 490: New Schedule = 97.0
# Flight 1377: New Schedule = 194.0
# Flight 321: New Schedule = 85.0
# Flight 1557: New Schedule = 208.0
# Flight 429: New Schedule = 193.0
# Flight 2395: New Schedule = 228.0
# Flight 82: New Schedule = 1.0
# Flight 955: New Schedule = 196.0
# Flight 533: New Schedule = 250.0
# Flight 724: New Schedule = 163.0
# Flight 2959: New Schedule = 7.0
# Flight 1230: New Schedule = 184.0
# Flight 2351: New Schedule = 131.0
# Flight 834: New Schedule = 127.0
# Flight 1157: New Schedule = 5.0
# Flight 1358: New Schedule = 132.0
# Flight 815: New Schedule = 223.0
# Flight 1574: New Schedule = 4.0
# Flight 1242: New Schedule = 26.0
# Flight 2785: New Schedule = 246.0
# Flight 2119: New Schedule = 181.0
# Flight 2725: New Schedule = 129.0
# Flight 2530: New Schedule = 204.0
# Flight 2168: New Schedule = 50.0
# Flight 910: New Schedule = 2.0
# Flight 966: New Schedule = 101.0
# Flight 2436: New Schedule = 248.0
# Flight 2107: New Schedule = 46.0
# Flight 1600: New Schedule = 191.0
# Flight 907: New Schedule = 166.0
# Flight 1164: New Schedule = 95.0
# Flight 560: New Schedule = 24.0
# Flight 2177: New Schedule = 260.0
# Flight 477: New Schedule = 127.0
# Flight 1387: New Schedule = 187.0
# Flight 536: New Schedule = 252.0
# Flight 2350: New Schedule = 257.0
# Flight 1525: New Schedule = 279.0
# Flight 1703: New Schedule = 8.0
# Flight 1686: New Schedule = 128.0
# Flight 2397: New Schedule = 160.0
# Flight 786: New Schedule = 161.0
# Flight 2568: New Schedule = 60.0
# Flight 1638: New Schedule = 283.0
# Flight 2463: New Schedule = 95.0
# Flight 2206: New Schedule = 175.0
# Flight 1507: New Schedule = 269.0
# Flight 2028: New Schedule = 131.0
# Flight 2600: New Schedule = 194.0
# Flight 1526: New Schedule = 58.0
# Flight 1302: New Schedule = 128.0
# Flight 2999: New Schedule = 233.0
# Flight 1289: New Schedule = 9.0
# Flight 2535: New Schedule = 255.0
# Flight 2634: New Schedule = 18.0
# Flight 664: New Schedule = 40.0
# Flight 1628: New Schedule = 250.0
# Flight 1162: New Schedule = 83.0
# Flight 2637: New Schedule = 43.0
# Flight 404: New Schedule = 191.0
# Flight 1410: New Schedule = 80.0
# Flight 2128: New Schedule = 142.0
# Flight 2570: New Schedule = 165.0
# Flight 748: New Schedule = 87.0
# Flight 750: New Schedule = 142.0
# Flight 893: New Schedule = 168.0
# Flight 1728: New Schedule = 237.0
# Flight 2191: New Schedule = 162.0
# Flight 2728: New Schedule = 81.0
# Flight 2095: New Schedule = 203.0
# Flight 896: New Schedule = 114.0
# Flight 1178: New Schedule = 71.0
# Flight 2635: New Schedule = 67.0
# Flight 1364: New Schedule = 157.0
# Flight 2194: New Schedule = 160.0
# Flight 739: New Schedule = 0.0
# Flight 2543: New Schedule = 28.0
# Flight 869: New Schedule = 143.0
# Flight 448: New Schedule = 30.0
# Flight 2435: New Schedule = 68.0
# Flight 1126: New Schedule = 257.0
# Flight 379: New Schedule = 11.0
# Flight 2241: New Schedule = 228.0
# Flight 2896: New Schedule = 87.0
# Flight 1609: New Schedule = 214.0
# Flight 2577: New Schedule = 209.0
# Flight 1603: New Schedule = 102.0
# Flight 1061: New Schedule = 82.0
# Flight 502: New Schedule = 87.0
# Flight 1606: New Schedule = 136.0
# Flight 1457: New Schedule = 158.0
# Flight 2503: New Schedule = 201.0
# Flight 2142: New Schedule = 32.0
# Flight 1205: New Schedule = 4.0
# Flight 1482: New Schedule = 59.0
# Flight 1056: New Schedule = 1.0
# Flight 1420: New Schedule = 194.0
# Flight 1466: New Schedule = 34.0
# Flight 1625: New Schedule = 143.0
# Flight 2280: New Schedule = 224.0
# Flight 2007: New Schedule = 243.0
# Flight 2524: New Schedule = 27.0
# Flight 1296: New Schedule = 207.0
# Flight 8771: New Schedule = 257.0
# Flight 846: New Schedule = 47.0
# Flight 1505: New Schedule = 53.0
# Flight 318: New Schedule = 255.0
# Flight 353: New Schedule = 257.0
# Flight 1380: New Schedule = 147.0
# Flight 853: New Schedule = 104.0
# Flight 2399: New Schedule = 122.0
# Flight 854: New Schedule = 255.0
# Flight 2267: New Schedule = 172.0
# Flight 758: New Schedule = 80.0
# Flight 1579: New Schedule = 254.0
# Flight 2548: New Schedule = 192.0
# Flight 1310: New Schedule = 149.0
# Flight 1723: New Schedule = 183.0
# Flight 2326: New Schedule = 144.0
# Flight 1357: New Schedule = 6.0
# Flight 2001: New Schedule = 222.0
# Flight 1742: New Schedule = 186.0
# Flight 2766: New Schedule = 276.0
# Flight 531: New Schedule = 223.0
# Flight 2367: New Schedule = 65.0
# Flight 2840: New Schedule = 270.0
# Flight 2832: New Schedule = 185.0
# Flight 2800: New Schedule = 84.0
# Flight 676: New Schedule = 226.0
# Flight 1271: New Schedule = 137.0
# Flight 2044: New Schedule = 214.0
# Flight 497: New Schedule = 56.0
# Flight 1519: New Schedule = 279.0
# Flight 2662: New Schedule = 88.0
# Flight 976: New Schedule = 141.0
# Flight 2992: New Schedule = 222.0
# Flight 2193: New Schedule = 24.0
# Flight 2413: New Schedule = 161.0
# Flight 937: New Schedule = 138.0
# Flight 1017: New Schedule = 50.0
# Flight 2700: New Schedule = 207.0
# Flight 1405: New Schedule = 110.0
# Flight 2893: New Schedule = 269.0
# Flight 2309: New Schedule = 169.0
# Flight 986: New Schedule = 148.0
# Flight 995: New Schedule = 67.0
# Flight 1290: New Schedule = 13.0
# Flight 2371: New Schedule = 113.0
# Flight 2888: New Schedule = 71.0
# Flight 2496: New Schedule = 283.0
# Flight 2714: New Schedule = 271.0
# Flight 2988: New Schedule = 165.0
# Flight 1323: New Schedule = 125.0
# Flight 1463: New Schedule = 57.0
# Flight 1716: New Schedule = 149.0
# Flight 795: New Schedule = 147.0
# Flight 1679: New Schedule = 37.0
# Flight 1356: New Schedule = 166.0
# Flight 2255: New Schedule = 252.0
# Flight 1727: New Schedule = 63.0
# Flight 2110: New Schedule = 210.0
# Flight 2245: New Schedule = 19.0
# Flight 2368: New Schedule = 150.0
# Flight 1402: New Schedule = 154.0
# Flight 2078: New Schedule = 223.0
# Flight 2946: New Schedule = 228.0
# Flight 1459: New Schedule = 13.0
# Flight 1292: New Schedule = 214.0
# Flight 2804: New Schedule = 37.0
# Flight 1640: New Schedule = 285.0
# Flight 2560: New Schedule = 3.0
# Flight 1363: New Schedule = 284.0
# Flight 2004: New Schedule = 174.0
# Flight 420: New Schedule = 93.0
# Flight 1517: New Schedule = 31.0
# Flight 1580: New Schedule = 216.0
# Flight 1011: New Schedule = 21.0
# Flight 1583: New Schedule = 220.0
# Flight 1573: New Schedule = 83.0
# Flight 2383: New Schedule = 247.0
# Flight 3338: New Schedule = 68.0
# Flight 4095: New Schedule = 206.0
# Flight 4033: New Schedule = 172.0
# Flight 4145: New Schedule = 137.0
# Flight 4469: New Schedule = 199.0
# Flight 4052: New Schedule = 246.0
# Flight 4154: New Schedule = 20.0
# Flight 3840: New Schedule = 188.0
# Flight 4488: New Schedule = 120.0
# Flight 2025: New Schedule = 208.0
# Flight 260: New Schedule = 86.0
# Flight 1516: New Schedule = 261.0
# Flight 1946: New Schedule = 231.0
# Flight 2967: New Schedule = 100.0
# Flight 2949: New Schedule = 37.0
# Flight 396: New Schedule = 78.0
# Flight 3196: New Schedule = 241.0
# Flight 1667: New Schedule = 224.0
# Flight 298: New Schedule = 76.0
# Flight 3493: New Schedule = 91.0
# Flight 668: New Schedule = 17.0
# Flight 3279: New Schedule = 64.0
# Flight 3342: New Schedule = 166.0
# Flight 2776: New Schedule = 229.0
# Flight 3412: New Schedule = 202.0
# Flight 2814: New Schedule = 138.0
# Flight 2797: New Schedule = 60.0
# Flight 733: New Schedule = 274.0
# Flight 2373: New Schedule = 52.0
# Flight 1872: New Schedule = 219.0
# Flight 1877: New Schedule = 1.0
# Flight 1619: New Schedule = 251.0
# Flight 564: New Schedule = 156.0
# Flight 2045: New Schedule = 89.0
# Flight 1337: New Schedule = 203.0
# Flight 3167: New Schedule = 186.0
# Flight 1914: New Schedule = 265.0
# Flight 2335: New Schedule = 89.0
# Flight 1570: New Schedule = 61.0
# Flight 3568: New Schedule = 165.0
# Flight 2208: New Schedule = 98.0
# Flight 3248: New Schedule = 36.0
# Flight 901: New Schedule = 54.0
# Flight 1861: New Schedule = 29.0
# Flight 3354: New Schedule = 58.0
# Flight 3324: New Schedule = 228.0
# Flight 1384: New Schedule = 130.0
# Flight 2721: New Schedule = 207.0
# Flight 931: New Schedule = 26.0
# Flight 2011: New Schedule = 190.0
# Flight 111: New Schedule = 51.0
# Flight 3447: New Schedule = 271.0
# Flight 3224: New Schedule = 282.0
# Flight 4329: New Schedule = 111.0
# Flight 4489: New Schedule = 92.0
# Flight 4470: New Schedule = 228.0
# Flight 4467: New Schedule = 135.0
# Flight 4518: New Schedule = 249.0
# Flight 4965: New Schedule = 63.0
# Flight 1967: New Schedule = 285.0
# Flight 1097: New Schedule = 31.0
# Flight 2719: New Schedule = 268.0
# Flight 1068: New Schedule = 258.0
# Flight 657: New Schedule = 249.0
# Flight 2464: New Schedule = 155.0
# Flight 833: New Schedule = 233.0
# Flight 1678: New Schedule = 201.0
# Flight 1646: New Schedule = 222.0
# Flight 989: New Schedule = 245.0
# Flight 2151: New Schedule = 127.0
# Flight 1673: New Schedule = 240.0
# Flight 2083: New Schedule = 207.0
# Flight 2826: New Schedule = 143.0
# Flight 8812: New Schedule = 283.0
# Flight 2611: New Schedule = 185.0
# Flight 2481: New Schedule = 178.0
# Flight 2237: New Schedule = 215.0
# Flight 1098: New Schedule = 97.0
# Flight 5420: New Schedule = 162.0
# Flight 8810: New Schedule = 148.0
# Flight 1564: New Schedule = 64.0
# Flight 454: New Schedule = 168.0
# Flight 2055: New Schedule = 82.0
# Flight 1748: New Schedule = 21.0
# Flight 271: New Schedule = 234.0
# Flight 2455: New Schedule = 63.0
# Flight 438: New Schedule = 105.0
# Flight 2616: New Schedule = 222.0
# Flight 1657: New Schedule = 155.0
# Flight 1829: New Schedule = 25.0
# Flight 1888: New Schedule = 144.0
# Flight 3473: New Schedule = 85.0
# Flight 563: New Schedule = 176.0
# Flight 2398: New Schedule = 207.0
# Flight 3052: New Schedule = 26.0
# Flight 3575: New Schedule = 238.0
# Flight 4544: New Schedule = 245.0
# Flight 830: New Schedule = 151.0
# Flight 1124: New Schedule = 204.0
# Flight 537: New Schedule = 180.0
# Flight 3257: New Schedule = 262.0
# Flight 717: New Schedule = 283.0
# Flight 361: New Schedule = 134.0
# Flight 3389: New Schedule = 97.0
# Flight 1268: New Schedule = 28.0
# Flight 988: New Schedule = 256.0
# Flight 1870: New Schedule = 172.0
# Flight 571: New Schedule = 43.0
# Flight 3180: New Schedule = 257.0
# Flight 5418: New Schedule = 71.0
# Flight 5364: New Schedule = 24.0
# Flight 2160: New Schedule = 9.0
# Flight 297: New Schedule = 111.0
# Flight 1154: New Schedule = 239.0
# Flight 129: New Schedule = 81.0
# Flight 456: New Schedule = 229.0
# Flight 894: New Schedule = 222.0
# Flight 1307: New Schedule = 55.0
# Flight 3065: New Schedule = 195.0
# Flight 1084: New Schedule = 287.0
# Flight 226: New Schedule = 149.0
# Flight 3915: New Schedule = 121.0
# Flight 386: New Schedule = 280.0
# Flight 3901: New Schedule = 153.0
# Flight 1440: New Schedule = 87.0
# Flight 1392: New Schedule = 49.0
# Flight 1784: New Schedule = 179.0
# Flight 1220: New Schedule = 170.0
# Flight 1445: New Schedule = 236.0
# Flight 2913: New Schedule = 81.0
# Flight 2527: New Schedule = 86.0
# Flight 158: New Schedule = 175.0
# Flight 197: New Schedule = 195.0
# Flight 2666: New Schedule = 150.0
# Flight 1927: New Schedule = 220.0
# Flight 120: New Schedule = 204.0
# Flight 224: New Schedule = 100.0
# Flight 504: New Schedule = 70.0
# Flight 2164: New Schedule = 255.0
# Flight 1378: New Schedule = 66.0
# Flight 1780: New Schedule = 215.0
# Flight 2062: New Schedule = 266.0
# Flight 2285: New Schedule = 65.0
# Flight 1577: New Schedule = 13.0
# Flight 284: New Schedule = 199.0
# Flight 553: New Schedule = 114.0
# Flight 779: New Schedule = 176.0
# Flight 972: New Schedule = 185.0
# Flight 2207: New Schedule = 265.0
# Flight 993: New Schedule = 284.0
# Flight 1757: New Schedule = 281.0
# Flight 1876: New Schedule = 86.0
# Flight 167: New Schedule = 235.0
# Flight 737: New Schedule = 189.0
# Flight 1119: New Schedule = 183.0
# Flight 513: New Schedule = 242.0
# Flight 2106: New Schedule = 104.0
# Flight 1476: New Schedule = 6.0
# Flight 3096: New Schedule = 90.0
# Flight 1002: New Schedule = 175.0
# Flight 636: New Schedule = 153.0
# Flight 2073: New Schedule = 167.0
# Flight 1859: New Schedule = 184.0
# Flight 2154: New Schedule = 81.0
# Flight 2710: New Schedule = 101.0
# Flight 166: New Schedule = 215.0
# Flight 2171: New Schedule = 87.0
# Flight 436: New Schedule = 41.0
# Flight 3019: New Schedule = 121.0
# Flight 2024: New Schedule = 228.0
# Flight 155: New Schedule = 86.0
# Flight 2178: New Schedule = 37.0
# Flight 673: New Schedule = 263.0
# Flight 2919: New Schedule = 74.0
# Flight 1713: New Schedule = 13.0
# Flight 5893: New Schedule = 123.0
# Flight 1943: New Schedule = 271.0
# Flight 2308: New Schedule = 258.0
# Flight 336: New Schedule = 211.0
# Flight 2169: New Schedule = 249.0
# Flight 1265: New Schedule = 93.0
# Flight 2175: New Schedule = 164.0
# Flight 3099: New Schedule = 110.0
# Flight 247: New Schedule = 171.0
# Flight 1041: New Schedule = 81.0
# Flight 1249: New Schedule = 272.0
# Flight 2088: New Schedule = 125.0
# Flight 1102: New Schedule = 94.0
# Flight 844: New Schedule = 232.0
# Flight 1882: New Schedule = 238.0
# Flight 2950: New Schedule = 213.0
# Flight 1231: New Schedule = 139.0
# Flight 656: New Schedule = 275.0
# Flight 2534: New Schedule = 198.0
# Flight 2299: New Schedule = 136.0
# Flight 2494: New Schedule = 126.0
# Flight 2450: New Schedule = 261.0
# Flight 1297: New Schedule = 111.0
# Flight 5046: New Schedule = 257.0
# Flight 923: New Schedule = 285.0
# Flight 1694: New Schedule = 257.0
# Flight 3467: New Schedule = 51.0
# Flight 4938: New Schedule = 42.0
# Flight 5058: New Schedule = 76.0
# Flight 4933: New Schedule = 77.0
# Flight 4924: New Schedule = 105.0
# Flight 5309: New Schedule = 238.0
# Flight 2165: New Schedule = 256.0
# Flight 2042: New Schedule = 71.0
# Flight 777: New Schedule = 227.0
# Flight 2066: New Schedule = 30.0
# Flight 735: New Schedule = 285.0
# Flight 544: New Schedule = 259.0
# Flight 2602: New Schedule = 241.0
# Flight 2883: New Schedule = 211.0
# Flight 2113: New Schedule = 161.0
# Flight 814: New Schedule = 226.0
# Flight 1620: New Schedule = 145.0
# Flight 2547: New Schedule = 254.0
# Flight 8806: New Schedule = 43.0
# Flight 2176: New Schedule = 203.0
# Flight 8787: New Schedule = 124.0
# Flight 2153: New Schedule = 108.0
# Flight 574: New Schedule = 225.0
# Flight 1394: New Schedule = 100.0
# Flight 463: New Schedule = 219.0
# Flight 444: New Schedule = 227.0
# Flight 1189: New Schedule = 163.0
# Flight 2210: New Schedule = 187.0
# Flight 1353: New Schedule = 72.0
# Flight 123: New Schedule = 180.0
# Flight 5382: New Schedule = 86.0
# Flight 5552: New Schedule = 162.0
# Flight 5330: New Schedule = 275.0
# Flight 4043: New Schedule = 232.0
# Flight 186: New Schedule = 216.0
# Flight 709: New Schedule = 16.0
# Flight 1074: New Schedule = 179.0
# Flight 1767: New Schedule = 262.0
# Flight 605: New Schedule = 241.0
# Flight 2228: New Schedule = 95.0
# Flight 2657: New Schedule = 124.0
# Flight 206: New Schedule = 99.0
# Flight 2931: New Schedule = 37.0
# Flight 2834: New Schedule = 158.0
# Flight 1083: New Schedule = 129.0
# Flight 329: New Schedule = 188.0
# Flight 2812: New Schedule = 153.0
# Flight 1536: New Schedule = 129.0
# Flight 125: New Schedule = 75.0
# Flight 1568: New Schedule = 257.0
# Flight 1758: New Schedule = 159.0
# Flight 2378: New Schedule = 257.0
# Flight 2794: New Schedule = 120.0
# Flight 1049: New Schedule = 224.0
# Flight 340: New Schedule = 210.0
# Flight 368: New Schedule = 75.0
# Flight 4609: New Schedule = 265.0
# Flight 4332: New Schedule = 209.0
# Flight 3441: New Schedule = 14.0
# Flight 5185: New Schedule = 130.0
# Flight 5022: New Schedule = 138.0
# Flight 793: New Schedule = 172.0
# Flight 879: New Schedule = 238.0
# Flight 548: New Schedule = 17.0
# Flight 543: New Schedule = 281.0
# Flight 1503: New Schedule = 1.0
# Flight 1149: New Schedule = 106.0
# Flight 3399: New Schedule = 67.0
# Flight 626: New Schedule = 239.0
# Flight 1167: New Schedule = 138.0
# Flight 1636: New Schedule = 165.0
# Flight 1339: New Schedule = 94.0
# Flight 1850: New Schedule = 194.0
# Flight 2477: New Schedule = 13.0
# Flight 1093: New Schedule = 171.0
# Flight 1933: New Schedule = 251.0
# Flight 1546: New Schedule = 30.0
# Flight 2599: New Schedule = 122.0
# Flight 1947: New Schedule = 168.0
# Flight 1150: New Schedule = 146.0
# Flight 1130: New Schedule = 35.0
# Flight 3017: New Schedule = 281.0
# Flight 1629: New Schedule = 25.0
# Flight 2039: New Schedule = 170.0
# Flight 617: New Schedule = 132.0
# Flight 2116: New Schedule = 170.0
# Flight 146: New Schedule = 18.0
# Flight 281: New Schedule = 191.0
# Flight 133: New Schedule = 207.0
# Flight 2418: New Schedule = 275.0
# Flight 124: New Schedule = 230.0
# Flight 1789: New Schedule = 151.0
# Flight 2540: New Schedule = 22.0
# Flight 679: New Schedule = 129.0
# Flight 1341: New Schedule = 10.0
# Flight 4766: New Schedule = 94.0
# Flight 4977: New Schedule = 76.0
# Flight 4759: New Schedule = 112.0
# Flight 4895: New Schedule = 233.0
# Flight 5505: New Schedule = 287.0
# Flight 4631: New Schedule = 32.0
# Flight 4743: New Schedule = 211.0
# Flight 4721: New Schedule = 10.0
# Flight 4808: New Schedule = 148.0
# Flight 4898: New Schedule = 96.0
# Flight 4748: New Schedule = 274.0
# Flight 4718: New Schedule = 253.0
# Flight 5449: New Schedule = 223.0
# Flight 4799: New Schedule = 199.0
# Flight 4819: New Schedule = 3.0
# Flight 5077: New Schedule = 107.0
# Flight 4643: New Schedule = 240.0
# Flight 4736: New Schedule = 3.0
# Flight 5401: New Schedule = 96.0
# Flight 4640: New Schedule = 113.0
# Flight 5415: New Schedule = 123.0
# Flight 4644: New Schedule = 127.0
# Flight 4649: New Schedule = 242.0
# Flight 4959: New Schedule = 23.0
# Flight 5490: New Schedule = 239.0
# Flight 4738: New Schedule = 286.0
# Flight 4968: New Schedule = 275.0
# Flight 4652: New Schedule = 185.0
# Flight 4768: New Schedule = 214.0
# Flight 4678: New Schedule = 197.0
# Flight 4858: New Schedule = 140.0
# Flight 5056: New Schedule = 250.0
# Flight 5442: New Schedule = 66.0
# Flight 4764: New Schedule = 246.0
# Flight 4871: New Schedule = 234.0
# Flight 4919: New Schedule = 234.0
# Flight 4914: New Schedule = 271.0
# Flight 5287: New Schedule = 134.0
# Flight 5352: New Schedule = 101.0
# Flight 4984: New Schedule = 164.0
# Flight 5092: New Schedule = 239.0
# Flight 5365: New Schedule = 150.0
# Flight 5532: New Schedule = 33.0
# Flight 5079: New Schedule = 233.0
# Flight 4796: New Schedule = 174.0
# Flight 5225: New Schedule = 68.0
# Flight 5497: New Schedule = 12.0
# Flight 4726: New Schedule = 204.0
# Flight 4867: New Schedule = 149.0
# Flight 4953: New Schedule = 161.0
# Flight 4827: New Schedule = 262.0
# Flight 5367: New Schedule = 146.0
# Flight 4844: New Schedule = 221.0
# Flight 5005: New Schedule = 140.0
# Flight 4892: New Schedule = 232.0
# Flight 5282: New Schedule = 90.0
# Flight 5059: New Schedule = 37.0
# Flight 5371: New Schedule = 25.0
# Flight 4790: New Schedule = 77.0
# Flight 4814: New Schedule = 279.0
# Flight 4903: New Schedule = 283.0
# Flight 334: New Schedule = 228.0
# Flight 376: New Schedule = 122.0
# Flight 2957: New Schedule = 121.0
# Flight 905: New Schedule = 81.0
# Flight 1125: New Schedule = 55.0
# Flight 1467: New Schedule = 213.0
# Flight 725: New Schedule = 225.0
# Flight 952: New Schedule = 76.0
# Flight 500: New Schedule = 248.0
# Flight 1527: New Schedule = 139.0
# Flight 1610: New Schedule = 264.0
# Flight 2541: New Schedule = 7.0
# Flight 1192: New Schedule = 250.0
# Flight 559: New Schedule = 75.0
# Flight 1656: New Schedule = 197.0
# Flight 839: New Schedule = 137.0
# Flight 1258: New Schedule = 56.0
# Flight 348: New Schedule = 179.0
# Flight 1109: New Schedule = 131.0
# Flight 922: New Schedule = 235.0
# Flight 2129: New Schedule = 105.0
# Flight 392: New Schedule = 22.0
# Flight 455: New Schedule = 31.0
# Flight 337: New Schedule = 202.0
# Flight 842: New Schedule = 136.0
# Flight 1014: New Schedule = 258.0
# Flight 2729: New Schedule = 145.0
# Flight 316: New Schedule = 247.0
# Flight 1494: New Schedule = 108.0
# Flight 2243: New Schedule = 95.0
# Flight 2429: New Schedule = 190.0
# Flight 1500: New Schedule = 96.0
# Flight 2215: New Schedule = 55.0
# Flight 1134: New Schedule = 6.0
# Flight 699: New Schedule = 7.0
# Flight 352: New Schedule = 60.0
# Flight 1069: New Schedule = 69.0
# Flight 2415: New Schedule = 151.0
# Flight 2786: New Schedule = 12.0
# Flight 1739: New Schedule = 122.0
# Flight 542: New Schedule = 63.0
# Flight 1572: New Schedule = 81.0
# Flight 394: New Schedule = 67.0
# Flight 2818: New Schedule = 266.0
# Flight 2017: New Schedule = 194.0
# Flight 514: New Schedule = 230.0
# Flight 2462: New Schedule = 77.0
# Flight 2704: New Schedule = 153.0
# Flight 2747: New Schedule = 13.0
# Flight 798: New Schedule = 195.0
# Flight 1330: New Schedule = 39.0
# Flight 2031: New Schedule = 154.0
# Flight 707: New Schedule = 99.0
# Flight 1473: New Schedule = 75.0
# Flight 1634: New Schedule = 206.0
# Flight 2523: New Schedule = 74.0
# Flight 1132: New Schedule = 170.0
# Flight 983: New Schedule = 111.0
# Flight 2538: New Schedule = 0.0
# Flight 1722: New Schedule = 63.0
# Flight 1367: New Schedule = 121.0
# Flight 2636: New Schedule = 240.0
# Flight 1173: New Schedule = 32.0
# Flight 2374: New Schedule = 214.0
# Flight 488: New Schedule = 130.0
# Flight 953: New Schedule = 241.0
# Flight 2730: New Schedule = 241.0
# Flight 1311: New Schedule = 247.0
# Flight 2691: New Schedule = 203.0
# Flight 2904: New Schedule = 230.0
# Flight 2936: New Schedule = 215.0
# Flight 2952: New Schedule = 120.0
# Flight 461: New Schedule = 93.0
# Flight 1027: New Schedule = 207.0
# Flight 2019: New Schedule = 253.0
# Flight 2934: New Schedule = 67.0
# Flight 1397: New Schedule = 39.0
# Flight 710: New Schedule = 4.0
# Flight 875: New Schedule = 277.0
# Flight 722: New Schedule = 255.0
# Flight 860: New Schedule = 159.0
# Flight 346: New Schedule = 278.0
# Flight 2525: New Schedule = 276.0
# Flight 2987: New Schedule = 59.0
# Flight 973: New Schedule = 165.0
# Flight 2232: New Schedule = 93.0
# Flight 2557: New Schedule = 70.0
# Flight 2554: New Schedule = 208.0
# Flight 890: New Schedule = 275.0
# Flight 1605: New Schedule = 54.0
# Flight 363: New Schedule = 70.0
# Flight 665: New Schedule = 37.0
# Flight 848: New Schedule = 171.0
# Flight 1344: New Schedule = 32.0
# Flight 2163: New Schedule = 214.0
# Flight 2147: New Schedule = 282.0
# Flight 687: New Schedule = 2.0
# Flight 2035: New Schedule = 212.0
# Flight 2181: New Schedule = 163.0
# Flight 2488: New Schedule = 62.0
# Flight 759: New Schedule = 216.0
# Flight 967: New Schedule = 191.0
# Flight 2109: New Schedule = 131.0
# Flight 2376: New Schedule = 175.0
# Flight 2908: New Schedule = 16.0
# Flight 932: New Schedule = 180.0
# Flight 2856: New Schedule = 3.0
# Flight 2058: New Schedule = 201.0
# Flight 2838: New Schedule = 23.0
# Flight 2707: New Schedule = 91.0
# Flight 2623: New Schedule = 187.0
# Flight 946: New Schedule = 111.0
# Flight 2093: New Schedule = 262.0
# Flight 1464: New Schedule = 240.0
# Flight 2162: New Schedule = 264.0
# Flight 2708: New Schedule = 261.0
# Flight 700: New Schedule = 107.0
# Flight 2091: New Schedule = 52.0
# Flight 2575: New Schedule = 79.0
# Flight 2038: New Schedule = 125.0
# Flight 2803: New Schedule = 256.0
# ...
# Flight 956: New Schedule = 203.0
# Flight 528: New Schedule = 203.0
# Flight 1058: New Schedule = 203.0
# Flight 829: New Schedule = 202.0
# Flight 1527: New Schedule = 202.0
# Flight 1610: New Schedule = 202.0
# Flight 2473: New Schedule = 202.0
# Flight 501: New Schedule = 202.0
# Flight 740: New Schedule = 202.0
# Flight 794: New Schedule = 202.0
# Flight 1031: New Schedule = 202.0
# Flight 2200: New Schedule = 202.0
# Flight 723: New Schedule = 202.0
# Flight 423: New Schedule = 202.0
# Flight 839: New Schedule = 202.0
# Flight 749: New Schedule = 202.0
# Flight 790: New Schedule = 202.0
# Flight 947: New Schedule = 202.0
# Flight 2138: New Schedule = 201.0
# Flight 816: New Schedule = 201.0
# Flight 487: New Schedule = 201.0
# Flight 734: New Schedule = 201.0
# Flight 1591: New Schedule = 201.0
# Flight 944: New Schedule = 201.0
# Flight 2051: New Schedule = 201.0
# Flight 392: New Schedule = 201.0
# Flight 378: New Schedule = 201.0
# Flight 1682: New Schedule = 201.0
# Flight 502: New Schedule = 201.0
# Flight 1014: New Schedule = 201.0
# Flight 2233: New Schedule = 201.0
# Flight 2729: New Schedule = 201.0
# Flight 316: New Schedule = 201.0
# Flight 1170: New Schedule = 200.0
# Flight 1531: New Schedule = 200.0
# Flight 543: New Schedule = 200.0
# Flight 2584: New Schedule = 200.0
# Flight 2215: New Schedule = 200.0
# Flight 534: New Schedule = 200.0
# Flight 1134: New Schedule = 200.0
# Flight 2124: New Schedule = 200.0
# Flight 898: New Schedule = 200.0
# Flight 2149: New Schedule = 200.0
# Flight 506: New Schedule = 200.0
# Flight 375: New Schedule = 200.0
# Flight 471: New Schedule = 200.0
# Flight 2539: New Schedule = 200.0
# Flight 2592: New Schedule = 200.0
# Flight 2914: New Schedule = 199.0
# Flight 2983: New Schedule = 199.0
# Flight 1676: New Schedule = 199.0
# Flight 2865: New Schedule = 199.0
# Flight 1739: New Schedule = 199.0
# Flight 493: New Schedule = 199.0
# Flight 1572: New Schedule = 199.0
# Flight 2818: New Schedule = 199.0
# Flight 2017: New Schedule = 199.0
# Flight 2117: New Schedule = 199.0
# Flight 660: New Schedule = 199.0
# Flight 2948: New Schedule = 199.0
# Flight 2747: New Schedule = 199.0
# Flight 1284: New Schedule = 199.0
# Flight 1251: New Schedule = 199.0
# Flight 1330: New Schedule = 198.0
# Flight 2031: New Schedule = 198.0
# Flight 707: New Schedule = 198.0
# Flight 1634: New Schedule = 198.0
# Flight 1609: New Schedule = 198.0
# Flight 2523: New Schedule = 198.0
# Flight 1458: New Schedule = 198.0
# Flight 2354: New Schedule = 198.0
# Flight 2970: New Schedule = 198.0
# Flight 492: New Schedule = 198.0
# Flight 539: New Schedule = 198.0
# Flight 781: New Schedule = 198.0
# Flight 1229: New Schedule = 198.0
# Flight 2374: New Schedule = 198.0
# Flight 2750: New Schedule = 198.0
# Flight 953: New Schedule = 197.0
# Flight 2312: New Schedule = 197.0
# Flight 2730: New Schedule = 197.0
# Flight 2938: New Schedule = 197.0
# Flight 1311: New Schedule = 197.0
# Flight 2904: New Schedule = 197.0
# Flight 2064: New Schedule = 197.0
# Flight 2952: New Schedule = 197.0
# Flight 461: New Schedule = 197.0
# Flight 2019: New Schedule = 197.0
# Flight 2934: New Schedule = 197.0
# Flight 1397: New Schedule = 197.0
# Flight 1508: New Schedule = 197.0
# Flight 825: New Schedule = 197.0
# Flight 414: New Schedule = 197.0
# Flight 926: New Schedule = 196.0
# Flight 346: New Schedule = 196.0
# Flight 840: New Schedule = 196.0
# Flight 2525: New Schedule = 196.0
# Flight 1588: New Schedule = 196.0
# Flight 2232: New Schedule = 196.0
# Flight 2377: New Schedule = 196.0
# Flight 2626: New Schedule = 196.0
# Flight 890: New Schedule = 196.0
# Flight 1605: New Schedule = 196.0
# Flight 665: New Schedule = 196.0
# Flight 927: New Schedule = 196.0
# Flight 2163: New Schedule = 196.0
# Flight 2147: New Schedule = 196.0
# Flight 687: New Schedule = 196.0
# Flight 2035: New Schedule = 195.0
# Flight 2113: New Schedule = 195.0
# Flight 759: New Schedule = 195.0
# Flight 2109: New Schedule = 195.0
# Flight 2376: New Schedule = 195.0
# Flight 2635: New Schedule = 195.0
# Flight 2908: New Schedule = 195.0
# Flight 968: New Schedule = 195.0
# Flight 2549: New Schedule = 195.0
# Flight 2058: New Schedule = 195.0
# Flight 793: New Schedule = 195.0
# Flight 2828: New Schedule = 195.0
# Flight 2369: New Schedule = 195.0
# Flight 946: New Schedule = 195.0
# Flight 2555: New Schedule = 195.0
# Flight 2100: New Schedule = 194.0
# Flight 1039: New Schedule = 194.0
# Flight 1625: New Schedule = 194.0
# Flight 1663: New Schedule = 194.0
# Flight 2655: New Schedule = 194.0
# Flight 658: New Schedule = 194.0
# Flight 2021: New Schedule = 194.0
# Flight 2038: New Schedule = 194.0
# Flight 2803: New Schedule = 194.0
# Flight 1035: New Schedule = 194.0
# Flight 406: New Schedule = 194.0
# Flight 2861: New Schedule = 194.0
# Flight 398: New Schedule = 194.0
# Flight 904: New Schedule = 194.0
# Flight 2465: New Schedule = 194.0
# Flight 2956: New Schedule = 193.0
# Flight 2632: New Schedule = 193.0
# Flight 1106: New Schedule = 193.0
# Flight 2282: New Schedule = 193.0
# Flight 2962: New Schedule = 193.0
# Flight 329: New Schedule = 193.0
# Flight 830: New Schedule = 193.0
# Flight 741: New Schedule = 193.0
# Flight 572: New Schedule = 193.0
# Flight 2276: New Schedule = 193.0
# Flight 525: New Schedule = 193.0
# Flight 1008: New Schedule = 193.0
# Flight 2927: New Schedule = 193.0
# Flight 2043: New Schedule = 193.0
# Flight 691: New Schedule = 193.0
# Flight 1006: New Schedule = 192.0
# Flight 1110: New Schedule = 192.0
# Flight 1333: New Schedule = 192.0
# Flight 1057: New Schedule = 192.0
# Flight 765: New Schedule = 192.0
# Flight 1217: New Schedule = 192.0
# Flight 2077: New Schedule = 192.0
# Flight 1950: New Schedule = 192.0
# Flight 555: New Schedule = 192.0
# Flight 1198: New Schedule = 192.0
# Flight 2912: New Schedule = 192.0
# Flight 1030: New Schedule = 192.0
# Flight 1047: New Schedule = 192.0
# Flight 966: New Schedule = 192.0
# Flight 2654: New Schedule = 192.0
# Flight 1343: New Schedule = 191.0
# Flight 1587: New Schedule = 191.0
# Flight 2103: New Schedule = 191.0
# Flight 1175: New Schedule = 191.0
# Flight 2774: New Schedule = 191.0
# Flight 753: New Schedule = 191.0
# Flight 1489: New Schedule = 191.0
# Flight 1142: New Schedule = 191.0
# Flight 2251: New Schedule = 191.0
# Flight 1096: New Schedule = 191.0
# Flight 1196: New Schedule = 191.0
# Flight 1340: New Schedule = 191.0
# Flight 1576: New Schedule = 191.0
# Flight 2526: New Schedule = 191.0
# Flight 897: New Schedule = 191.0
# Flight 1324: New Schedule = 190.0
# Flight 1155: New Schedule = 190.0
# Flight 2552: New Schedule = 190.0
# Flight 2923: New Schedule = 190.0
# Flight 1150: New Schedule = 190.0
# Flight 1658: New Schedule = 190.0
# Flight 1172: New Schedule = 190.0
# Flight 2753: New Schedule = 190.0
# Flight 2894: New Schedule = 190.0
# Flight 1546: New Schedule = 190.0
# Flight 2338: New Schedule = 190.0
# Flight 2875: New Schedule = 190.0
# Flight 2848: New Schedule = 190.0
# Flight 1678: New Schedule = 190.0
# Flight 1218: New Schedule = 190.0
# Flight 2720: New Schedule = 189.0
# Flight 1274: New Schedule = 189.0
# Flight 2451: New Schedule = 189.0
# Flight 1883: New Schedule = 189.0
# Flight 2205: New Schedule = 189.0
# Flight 2559: New Schedule = 189.0
# Flight 961: New Schedule = 189.0
# Flight 1264: New Schedule = 189.0
# Flight 1153: New Schedule = 189.0
# Flight 1328: New Schedule = 189.0
# Flight 2484: New Schedule = 189.0
# Flight 2746: New Schedule = 189.0
# Flight 1720: New Schedule = 189.0
# Flight 2590: New Schedule = 189.0
# Flight 1664: New Schedule = 189.0
# Flight 2400: New Schedule = 188.0
# Flight 2738: New Schedule = 188.0
# Flight 1280: New Schedule = 188.0
# Flight 1227: New Schedule = 188.0
# Flight 401: New Schedule = 188.0
# Flight 447: New Schedule = 188.0
# Flight 855: New Schedule = 188.0
# Flight 653: New Schedule = 188.0
# Flight 2739: New Schedule = 188.0
# Flight 1279: New Schedule = 188.0
# Flight 452: New Schedule = 188.0
# Flight 888: New Schedule = 188.0
# Flight 950: New Schedule = 188.0
# Flight 2749: New Schedule = 188.0
# Flight 874: New Schedule = 188.0
# Flight 1003: New Schedule = 187.0
# Flight 1372: New Schedule = 187.0
# Flight 1712: New Schedule = 187.0
# Flight 2643: New Schedule = 187.0
# Flight 2719: New Schedule = 187.0
# Flight 1265: New Schedule = 187.0
# Flight 2859: New Schedule = 187.0
# Flight 2131: New Schedule = 187.0
# Flight 1024: New Schedule = 187.0
# Flight 2063: New Schedule = 187.0
# Flight 1347: New Schedule = 187.0
# Flight 2472: New Schedule = 187.0
# Flight 826: New Schedule = 187.0
# Flight 2846: New Schedule = 187.0
# Flight 1213: New Schedule = 187.0
# Flight 2544: New Schedule = 186.0
# Flight 359: New Schedule = 186.0
# Flight 1443: New Schedule = 186.0
# Flight 780: New Schedule = 186.0
# Flight 1646: New Schedule = 186.0
# Flight 2937: New Schedule = 186.0
# Flight 1661: New Schedule = 186.0
# Flight 812: New Schedule = 186.0
# Flight 1418: New Schedule = 186.0
# Flight 1746: New Schedule = 186.0
# Flight 2199: New Schedule = 186.0
# Flight 916: New Schedule = 186.0
# Flight 1037: New Schedule = 186.0
# Flight 2060: New Schedule = 186.0
# Flight 373: New Schedule = 186.0
# Flight 2795: New Schedule = 185.0
# Flight 2159: New Schedule = 185.0
# Flight 2901: New Schedule = 185.0
# Flight 434: New Schedule = 185.0
# Flight 2391: New Schedule = 185.0
# Flight 2624: New Schedule = 185.0
# Flight 1732: New Schedule = 185.0
# Flight 721: New Schedule = 185.0
# Flight 2296: New Schedule = 185.0
# Flight 682: New Schedule = 185.0
# Flight 1121: New Schedule = 185.0
# Flight 2448: New Schedule = 185.0
# Flight 478: New Schedule = 185.0
# Flight 2062: New Schedule = 185.0
# Flight 2958: New Schedule = 185.0
# Flight 2123: New Schedule = 184.0
# Flight 2161: New Schedule = 184.0
# Flight 2151: New Schedule = 184.0
# Flight 2065: New Schedule = 184.0
# Flight 2086: New Schedule = 184.0
# Flight 2195: New Schedule = 184.0
# Flight 2820: New Schedule = 184.0
# Flight 2681: New Schedule = 184.0
# Flight 1451: New Schedule = 184.0
# Flight 2392: New Schedule = 184.0
# Flight 2445: New Schedule = 184.0
# Flight 510: New Schedule = 184.0
# Flight 2900: New Schedule = 184.0
# Flight 2260: New Schedule = 184.0
# Flight 2425: New Schedule = 184.0
# Flight 1097: New Schedule = 183.0
# Flight 1437: New Schedule = 183.0
# Flight 1677: New Schedule = 183.0
# Flight 2615: New Schedule = 183.0
# Flight 2132: New Schedule = 183.0
# Flight 507: New Schedule = 183.0
# Flight 903: New Schedule = 183.0
# Flight 2621: New Schedule = 183.0
# Flight 2198: New Schedule = 183.0
# Flight 2004: New Schedule = 183.0
# Flight 2097: New Schedule = 183.0
# Flight 2496: New Schedule = 183.0
# Flight 2022: New Schedule = 183.0
# Flight 2213: New Schedule = 183.0
# Flight 2873: New Schedule = 183.0
# Flight 2009: New Schedule = 182.0
# Flight 2880: New Schedule = 182.0
# Flight 1200: New Schedule = 182.0
# Flight 2360: New Schedule = 182.0
# Flight 2423: New Schedule = 182.0
# Flight 2762: New Schedule = 182.0
# Flight 2777: New Schedule = 182.0
# Flight 2851: New Schedule = 182.0
# Flight 2902: New Schedule = 182.0
# Flight 2346: New Schedule = 182.0
# Flight 2014: New Schedule = 182.0
# Flight 2718: New Schedule = 182.0
# Flight 2226: New Schedule = 182.0
# Flight 2644: New Schedule = 182.0
# Flight 2187: New Schedule = 182.0
# Flight 2754: New Schedule = 181.0
# Flight 2871: New Schedule = 181.0
# Flight 2819: New Schedule = 181.0
# Flight 827: New Schedule = 181.0
# Flight 2271: New Schedule = 181.0
# Flight 2275: New Schedule = 181.0
# Flight 2651: New Schedule = 181.0
# Flight 2763: New Schedule = 181.0
# Flight 509: New Schedule = 181.0
# Flight 2887: New Schedule = 181.0
# Flight 2349: New Schedule = 181.0
# Flight 2907: New Schedule = 181.0
# Flight 338: New Schedule = 181.0
# Flight 2229: New Schedule = 181.0
# Flight 2068: New Schedule = 181.0
# Flight 2144: New Schedule = 180.0
# Flight 2362: New Schedule = 180.0
# Flight 2332: New Schedule = 180.0
# Flight 2771: New Schedule = 180.0
# Flight 2953: New Schedule = 180.0
# Flight 2461: New Schedule = 180.0
# Flight 2612: New Schedule = 180.0
# Flight 3383: New Schedule = 180.0
# Flight 3799: New Schedule = 180.0
# Flight 4086: New Schedule = 180.0
# Flight 3885: New Schedule = 180.0
# Flight 3983: New Schedule = 180.0
# Flight 4016: New Schedule = 180.0
# Flight 3527: New Schedule = 180.0
# Flight 3753: New Schedule = 180.0
# Flight 3896: New Schedule = 179.0
# Flight 3780: New Schedule = 179.0
# Flight 3929: New Schedule = 179.0
# Flight 3955: New Schedule = 179.0
# Flight 3686: New Schedule = 179.0
# Flight 3908: New Schedule = 179.0
# Flight 3862: New Schedule = 179.0
# Flight 3872: New Schedule = 179.0
# Flight 3864: New Schedule = 179.0
# Flight 3816: New Schedule = 179.0
# Flight 3999: New Schedule = 179.0
# Flight 3639: New Schedule = 179.0
# Flight 3880: New Schedule = 179.0
# Flight 3907: New Schedule = 179.0
# Flight 3962: New Schedule = 179.0
# Flight 3581: New Schedule = 178.0
# Flight 3719: New Schedule = 178.0
# Flight 4004: New Schedule = 178.0
# Flight 3778: New Schedule = 178.0
# Flight 3782: New Schedule = 178.0
# Flight 3963: New Schedule = 178.0
# Flight 5469: New Schedule = 178.0
# Flight 4650: New Schedule = 178.0
# Flight 980: New Schedule = 178.0
# Flight 1718: New Schedule = 178.0
# Flight 2980: New Schedule = 178.0
# Flight 1055: New Schedule = 178.0
# Flight 8802: New Schedule = 178.0
# Flight 1478: New Schedule = 178.0
# Flight 8819: New Schedule = 178.0
# Flight 2287: New Schedule = 177.0
# Flight 2821: New Schedule = 177.0
# Flight 1889: New Schedule = 177.0
# Flight 2081: New Schedule = 177.0
# Flight 697: New Schedule = 177.0
# Flight 2741: New Schedule = 177.0
# Flight 2487: New Schedule = 177.0
# Flight 126: New Schedule = 177.0
# Flight 3477: New Schedule = 177.0
# Flight 4415: New Schedule = 177.0
# Flight 4326: New Schedule = 177.0
# Flight 4583: New Schedule = 177.0
# Flight 5236: New Schedule = 177.0
# Flight 4901: New Schedule = 177.0
# Flight 4129: New Schedule = 177.0
# Flight 2989: New Schedule = 176.0
# Flight 3372: New Schedule = 176.0
# Flight 4152: New Schedule = 176.0
# Flight 2961: New Schedule = 176.0
# Flight 4897: New Schedule = 176.0
# Flight 5056: New Schedule = 176.0
# Flight 4713: New Schedule = 176.0
# Flight 4910: New Schedule = 176.0
# Flight 374: New Schedule = 176.0
# Flight 488: New Schedule = 176.0
# Flight 2826: New Schedule = 176.0
# Flight 704: New Schedule = 176.0
# Flight 1565: New Schedule = 176.0
# Flight 2175: New Schedule = 176.0
# Flight 718: New Schedule = 176.0
# Flight 1462: New Schedule = 175.0
# Flight 1374: New Schedule = 175.0
# Flight 2510: New Schedule = 175.0
# Flight 3874: New Schedule = 175.0
# Flight 3538: New Schedule = 175.0
# Flight 3903: New Schedule = 175.0
# Flight 4453: New Schedule = 175.0
# Flight 4366: New Schedule = 175.0
# Flight 3666: New Schedule = 175.0
# Flight 3405: New Schedule = 175.0
# Flight 4879: New Schedule = 175.0
# Flight 8786: New Schedule = 175.0
# Flight 1042: New Schedule = 175.0
# Flight 1098: New Schedule = 175.0
# Flight 4829: New Schedule = 175.0
# Flight 4780: New Schedule = 174.0
# Flight 4957: New Schedule = 174.0
# Flight 4795: New Schedule = 174.0
# Flight 4818: New Schedule = 174.0
# Flight 4715: New Schedule = 174.0
# Flight 4684: New Schedule = 174.0
# Flight 2825: New Schedule = 174.0
# Flight 924: New Schedule = 174.0
# Flight 919: New Schedule = 174.0
# Flight 892: New Schedule = 174.0
# Flight 2659: New Schedule = 174.0
# Flight 2690: New Schedule = 174.0
# Flight 1490: New Schedule = 174.0
# Flight 2638: New Schedule = 174.0
# Flight 2639: New Schedule = 174.0
# Flight 2420: New Schedule = 173.0
# Flight 2430: New Schedule = 173.0
# Flight 661: New Schedule = 173.0
# Flight 2879: New Schedule = 173.0
# Flight 2020: New Schedule = 173.0
# Flight 2752: New Schedule = 173.0
# Flight 2139: New Schedule = 173.0
# Flight 1063: New Schedule = 173.0
# Flight 2972: New Schedule = 173.0
# Flight 2772: New Schedule = 173.0
# Flight 925: New Schedule = 173.0
# Flight 942: New Schedule = 173.0
# Flight 2629: New Schedule = 173.0
# Flight 2322: New Schedule = 173.0
# Flight 2869: New Schedule = 173.0
# Flight 2406: New Schedule = 172.0
# Flight 322: New Schedule = 172.0
# Flight 3981: New Schedule = 172.0
# Flight 3546: New Schedule = 172.0
# Flight 3941: New Schedule = 172.0
# Flight 3952: New Schedule = 172.0
# Flight 3939: New Schedule = 172.0
# Flight 2268: New Schedule = 172.0
# Flight 934: New Schedule = 172.0
# Flight 2483: New Schedule = 172.0
# Flight 900: New Schedule = 172.0
# Flight 5500: New Schedule = 172.0
# Flight 2042: New Schedule = 172.0
# Flight 2218: New Schedule = 172.0
# Flight 5139: New Schedule = 172.0
# Flight 5461: New Schedule = 171.0
# Flight 5397: New Schedule = 171.0
# Flight 4932: New Schedule = 171.0
# Flight 1021: New Schedule = 171.0
# Flight 2230: New Schedule = 171.0

# %%
# Assuming 'arrival_delay' and 'departure_delay' columns exist in your original dataset
initial_arrival_delay = data[data['DEST'] == 'ATL']['ARR_DELAY'].sum()  # Total initial delay for arrival flights
initial_departure_delay = data[data['ORIGIN'] == 'ATL']['DEP_DELAY'].sum()  # Total initial delay for departure flights

# After optimizing the model, calculate the optimized delays
optimized_arrival_delay = 0
optimized_departure_delay = 0

for i in arrival_flights:
    # Find the first time slot where the flight is scheduled after optimization
    for t in range(T):
        if w_arr[i, t].X > 0:
            optimized_arrival_delay += max(0, 5*t - data[data['OP_CARRIER_FL_NUM'] == i]['CRS_ARR_TIME'].values[0])   # Assuming 5 min intervals

for j in departure_flights:
    # Find the first time slot where the flight is scheduled after optimization
    for t in range(T):
        if w_dep[j, t].X > 0:
            optimized_departure_delay += max(0, 5*t - data[data['OP_CARRIER_FL_NUM'] == j]['CRS_DEP_TIME'].values[0])  # Assuming 5 min intervals

# Calculate total initial and optimized delays
total_initial_delay = initial_arrival_delay + initial_departure_delay
total_optimized_delay = optimized_arrival_delay + optimized_departure_delay

# Calculate reduction in delay
reduction_in_delay = total_initial_delay - total_optimized_delay

# Print results
print(f"Total Initial Delay: {total_initial_delay} minutes")
print(f"Total Optimized Delay: {total_optimized_delay} minutes")
print(f"Reduction in Delay: {reduction_in_delay} minutes")
# Out:
# Total Initial Delay: 553817.0 minutes
# Total Optimized Delay: 257199 minutes
# Reduction in Delay: 296618.0 minutes

# %%
print(f"Percentage reduction in delay:{reduction_in_delay/total_initial_delay*100}%")
# Out:
# Percentage reduction in delay:53.558847055976976%

# %%
# Initialize an empty DataFrame to store results
results_df = pd.DataFrame(columns=['Day', 'Flight Number', 'Original Time', 'New Time', 'Type'])

# Get the unique days in the dataset
days_in_month = data['DAY_OF_MONTH'].unique()

# Loop through each day in the month
for day in days_in_month:
    # Filter data for the current day
    day_data = data[data['DAY_OF_MONTH'] == day]
    
    # Loop through each arrival flight for this day
    for i in arrival_flights:
        # Check if the flight exists in the data for the current day
        if i in day_data['OP_CARRIER_FL_NUM'].values:
            # Original arrival time
            original_arrival = day_data[day_data['OP_CARRIER_FL_NUM'] == i]['CRS_ARR_TIME'].values[0]
            # Rescheduled arrival time in minutes
            new_arrival_time = sum(t * 5 for t in range(T) if w_arr[i, t].X > 0)
            
            # Append data to the results DataFrame
            results_df = pd.concat([
                results_df, 
                pd.DataFrame({
                    'Day': [day],
                    'Flight Number': [i],
                    'Original Time': [original_arrival],
                    'New Time': [new_arrival_time],
                    'Type': ['Arrival']
                })
            ], ignore_index=True)
    
    # Loop through each departure flight for this day
    for j in departure_flights:
        # Check if the flight exists in the data for the current day
        if j in day_data['OP_CARRIER_FL_NUM'].values:
            # Original departure time
            original_departure = day_data[day_data['OP_CARRIER_FL_NUM'] == j]['CRS_DEP_TIME'].values[0]
            # Rescheduled departure time in minutes
            new_departure_time = sum(t * 5 for t in range(T) if w_dep[j, t].X > 0)
            
            # Append data to the results DataFrame
            results_df = pd.concat([
                results_df, 
                pd.DataFrame({
                    'Day': [day],
                    'Flight Number': [j],
                    'Original Time': [original_departure],
                    'New Time': [new_departure_time],
                    'Type': ['Departure']
                })
            ], ignore_index=True)

# Display the resulting DataFrame
print(results_df)

# %%
results_df.to_csv("rescheduled1.csv")
